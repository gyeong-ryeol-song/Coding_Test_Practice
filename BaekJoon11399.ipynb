# %% [markdown]
# # 백준 11399번

# %%
n = int(input())

a = list(map(int,input().split()))

    
a.sort()

total = 0
current = 0
for i in a:
    current += i
    total += current
    
print(total)
# Out:
# 5
# 3 1 4 3 2
# 32
